# %% [markdown]
# <a href="https://colab.research.google.com/github/isafvan5/PyOpengl/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://images.unsplash.com/photo-1503023345310-bd7c1de61c7d?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8aHVtYW58ZW58MHx8MHx8fDA%3D&w=1000&q=80'
# Out:
# --2023-05-26 08:46:21--  https://images.unsplash.com/photo-1503023345310-bd7c1de61c7d?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8aHVtYW58ZW58MHx8MHx8fDA%3D&w=1000&q=80
# Resolving images.unsplash.com (images.unsplash.com)... 146.75.94.208, 2a04:4e42:6::720
# Connecting to images.unsplash.com (images.unsplash.com)|146.75.94.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 173261 (169K) [image/jpeg]
# Saving to: ‘photo-1503023345310-bd7c1de61c7d?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8aHVtYW58ZW58MHx8MHx8fDA=&w=1000&q=80’
#
# photo-1503023345310 100%[===================>] 169.20K  --.-KB/s    in 0.02s
#
# 2023-05-26 08:46:21 (8.75 MB/s) - ‘photo-1503023345310-bd7c1de61c7d?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8aHVtYW58ZW58MHx8MHx8fDA=&w=1000&q=80’ saved [173261/173261]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('/content/photo-1503023345310-bd7c1de61c7d?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8aHVtYW58ZW58MHx8MHx8fDA=&w=1000&q=80')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1250, 1000, 3)

# %%
print(img)
# Out:
# [[[243 244 246]
#   [243 244 246]
#   [243 244 246]
#   ...
#   [238 242 245]
#   [238 242 245]
#   [237 241 244]]
#
#  [[243 244 246]
#   [243 244 246]
#   [243 244 246]
#   ...
#   [238 242 245]
#   [238 242 245]
#   [237 241 244]]
#
#  [[243 244 246]
#   [243 244 246]
#   [243 244 246]
#   ...
#   [238 242 245]
#   [238 242 245]
#   [237 241 244]]
#
#  ...
#
#  [[ 34  25  28]
#   [ 34  25  28]
#   [ 34  25  28]
#   ...
#   [ 32  26  28]
#   [ 32  26  28]
#   [ 32  26  28]]
#
#  [[ 34  25  28]
#   [ 34  25  28]
#   [ 34  25  28]
#   ...
#   [ 33  27  29]
#   [ 32  26  28]
#   [ 32  26  28]]
#
#  [[ 34  25  28]
#   [ 34  25  28]
#   [ 34  25  28]
#   ...
#   [ 33  27  29]
#   [ 32  26  28]
#   [ 32  26  28]]]

# %%
img_plot=plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img=Image.open('/content/photo-1503023345310-bd7c1de61c7d?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8aHVtYW58ZW58MHx8MHx8fDA=&w=1000&q=80')
img_resized=img.resize((200,200))

# %%
img_resized=img.resize((200,200))

# %%
img_resized.save('man_image_resized.jpg')

# %%
img_res=mpimg.imread('/content/man_image_resized.jpg')
img_res_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
img=cv2.imread('/content/photo-1503023345310-bd7c1de61c7d?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8aHVtYW58ZW58MHx8MHx8fDA=&w=1000&q=80')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1250, 1000, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1250, 1000)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1000x1250 at 0x7FB4C3629C30>
